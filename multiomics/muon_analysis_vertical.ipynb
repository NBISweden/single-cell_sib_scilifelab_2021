# %% [markdown]
# # Multiomics analysis with `muon` - Vertical integration
#
# In this notebook we will perform exploratory analysis and joint dimensionality reduction on Multiome data of differentiating glutamatergic neurons from [Trevino et al.2020](https://www.biorxiv.org/content/10.1101/2020.12.29.424636v2.full). The original datasets can be downloaded following the instructions in https://github.com/GreenleafLab/brainchromatin. We subset to the excitatory neurons and progenitors and convert to `anndata` objects in the script `prep_data.Rmd`.

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as ad

# %%
import muon as mu

# %%
## Plotting utils
import matplotlib.pyplot as plt
import matplotlib

# %%
# pip install mofapy2

# %% [markdown]
# ## Load single-view data

# %% [markdown]
# The data for each omic view is stored in [`AnnData`](https://anndata.readthedocs.io/en/latest/index.html) format. An `AnnData` object allows us to store a matrix and add annotations to its different dimensions, defined as “observations” (i.e. cells), and measured “variables” (i.e. genes for the RNA view and peaks for the ATAC modalities).

# %%
rna_adata = sc.read_h5ad('./processed_data/Multiome_RNA_ext_trajectory_SCE.h5ad')
atac_adata = sc.read_h5ad('./processed_data/Multiome_ATAC_ext_trajectory_SCE.h5ad')

# %% [markdown]
# We can access the annotations on cells using `adata.obs`

# %%
rna_adata.obs
# Out:
#                                                                      Cell.ID  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA  hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA  hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC  hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC  hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG  hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG
# ...                                                                      ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT  hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA  hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT  hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG  hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA  hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA
#
#                                                   Sample.ID Sample.Age  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA  hft_ctx_w21_dc1r3_r1      pcw21
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA  hft_ctx_w21_dc1r3_r1      pcw21
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC  hft_ctx_w21_dc1r3_r1      pcw21
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC  hft_ctx_w21_dc1r3_r1      pcw21
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG  hft_ctx_w21_dc1r3_r1      pcw21
# ...                                                     ...        ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT  hft_ctx_w21_dc2r2_r2      pcw21
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA  hft_ctx_w21_dc2r2_r2      pcw21
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT  hft_ctx_w21_dc2r2_r2      pcw21
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG  hft_ctx_w21_dc2r2_r2      pcw21
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA  hft_ctx_w21_dc2r2_r2      pcw21
#
#                                       Sample.Batch      Cell.Barcode  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA     b2020_11  AAACAGCCAGCAATAA
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA     b2020_11  AAACATGCACGTTACA
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC     b2020_11  AAACGGATCCATAAGC
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC     b2020_11  AAACGGATCTTGACCC
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG     b2020_11  AAAGCAAGTGATTACG
# ...                                            ...               ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT     b2020_11  TTTGGTAAGAAAGCAT
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA     b2020_11  TTTGGTGCAACCCTAA
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT     b2020_11  TTTGGTGCAGTAGCCT
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG     b2020_11  TTTGTGAAGACAGGCG
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA     b2020_11  TTTGTGTTCGTCCTTA
#
#                                        RNA.Counts  RNA.Features  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA        2494          1435
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA        3485          1632
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC        3490          1967
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC        3331          1666
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG        2436          1414
# ...                                           ...           ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT        7089          2810
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA        4647          2095
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT        5505          2378
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG        4099          1935
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA        6520          2514
#
#                                       Dissociation.ID  percentMT  percentRibo  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA               A   0.000796     0.017516
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA               A   0.031098     0.039372
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC               A   0.028865     0.046585
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC               A   0.061920     0.049955
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG               A   0.038430     0.049060
# ...                                               ...        ...          ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT               B   0.052646     0.045346
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA               B   0.032583     0.029582
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT               B   0.008314     0.028556
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG               B   0.061999     0.044979
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA               B   0.001069     0.014207
#
#                                       seurat_clusters
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA             c10
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA              c0
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC              c1
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC              c0
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG              c1
# ...                                               ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT              c1
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA              c0
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT              c3
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG              c0
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA              c6
#
# [5374 rows x 11 columns]

# %%
atac_adata.obs
# Out:
#                                                                      Cell.ID  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA  hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA  hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC  hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC  hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG  hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG
# ...                                                                      ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT  hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA  hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT  hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG  hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA  hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA
#
#                                                   Sample.ID Sample.Age  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA  hft_ctx_w21_dc1r3_r1      pcw21
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA  hft_ctx_w21_dc1r3_r1      pcw21
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC  hft_ctx_w21_dc1r3_r1      pcw21
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC  hft_ctx_w21_dc1r3_r1      pcw21
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG  hft_ctx_w21_dc1r3_r1      pcw21
# ...                                                     ...        ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT  hft_ctx_w21_dc2r2_r2      pcw21
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA  hft_ctx_w21_dc2r2_r2      pcw21
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT  hft_ctx_w21_dc2r2_r2      pcw21
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG  hft_ctx_w21_dc2r2_r2      pcw21
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA  hft_ctx_w21_dc2r2_r2      pcw21
#
#                                       Sample.Batch      Cell.Barcode  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA     b2020_11  AAACAGCCAGCAATAA
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA     b2020_11  AAACATGCACGTTACA
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC     b2020_11  AAACGGATCCATAAGC
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC     b2020_11  AAACGGATCTTGACCC
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG     b2020_11  AAAGCAAGTGATTACG
# ...                                            ...               ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT     b2020_11  TTTGGTAAGAAAGCAT
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA     b2020_11  TTTGGTGCAACCCTAA
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT     b2020_11  TTTGGTGCAGTAGCCT
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG     b2020_11  TTTGTGAAGACAGGCG
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA     b2020_11  TTTGTGTTCGTCCTTA
#
#                                        RNA.Counts  RNA.Features  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA        2494          1435
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA        3485          1632
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC        3490          1967
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC        3331          1666
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG        2436          1414
# ...                                           ...           ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT        7089          2810
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA        4647          2095
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT        5505          2378
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG        4099          1935
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA        6520          2514
#
#                                       Dissociation.ID  percentMT  percentRibo  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA               A   0.000796     0.017516
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA               A   0.031098     0.039372
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC               A   0.028865     0.046585
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC               A   0.061920     0.049955
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG               A   0.038430     0.049060
# ...                                               ...        ...          ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT               B   0.052646     0.045346
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA               B   0.032583     0.029582
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT               B   0.008314     0.028556
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG               B   0.061999     0.044979
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA               B   0.001069     0.014207
#
#                                        ...  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA  ...
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA  ...
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC  ...
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC  ...
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG  ...
# ...                                    ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT  ...
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA  ...
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT  ...
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG  ...
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA  ...
#
#                                        CR_GEX.Reads.mapped.confidently.to.intergenic.regions  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA                                            0.04289
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA                                            0.04289
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC                                            0.04289
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC                                            0.04289
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG                                            0.04289
# ...                                                                                  ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT                                            0.04640
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA                                            0.04640
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT                                            0.04640
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG                                            0.04640
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA                                            0.04640
#
#                                        CR_GEX.Reads.mapped.confidently.to.intronic.regions  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA                                            0.53493
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA                                            0.53493
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC                                            0.53493
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC                                            0.53493
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG                                            0.53493
# ...                                                                                  ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT                                            0.54620
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA                                            0.54620
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT                                            0.54620
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG                                            0.54620
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA                                            0.54620
#
#                                        CR_GEX.Reads.mapped.confidently.to.transcriptome  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA                                           0.63963
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA                                           0.63963
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC                                           0.63963
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC                                           0.63963
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG                                           0.63963
# ...                                                                                 ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT                                           0.61601
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA                                           0.61601
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT                                           0.61601
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG                                           0.61601
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA                                           0.61601
#
#                                        CR_GEX.Reads.mapped.to.genome  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA                        0.94198
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA                        0.94198
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC                        0.94198
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC                        0.94198
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG                        0.94198
# ...                                                              ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT                        0.94263
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA                        0.94263
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT                        0.94263
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG                        0.94263
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA                        0.94263
#
#                                        CR_GEX.Reads.with.TSO  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA                0.05057
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA                0.05057
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC                0.05057
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC                0.05057
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG                0.05057
# ...                                                      ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT                0.09030
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA                0.09030
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT                0.09030
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG                0.09030
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA                0.09030
#
#                                        CR_GEX.Sequenced.read.pairs  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA                    224096641
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA                    224096641
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC                    224096641
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC                    224096641
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG                    224096641
# ...                                                            ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT                    194384797
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA                    194384797
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT                    194384797
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG                    194384797
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA                    194384797
#
#                                        CR_GEX.Total.genes.detected  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA                        28938
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA                        28938
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC                        28938
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC                        28938
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG                        28938
# ...                                                            ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT                        29301
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA                        29301
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT                        29301
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG                        29301
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA                        29301
#
#                                        CR_GEX.Valid.UMIs  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA            0.99941
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA            0.99941
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC            0.99941
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC            0.99941
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG            0.99941
# ...                                                  ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT            0.99939
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA            0.99939
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT            0.99939
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG            0.99939
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA            0.99939
#
#                                        CR_GEX.Valid.barcodes  seurat_clusters
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA                0.95564              c10
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA                0.95564               c0
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC                0.95564               c1
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC                0.95564               c0
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG                0.95564               c1
# ...                                                      ...              ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT                0.94950               c1
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA                0.94950               c0
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT                0.94950               c3
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG                0.94950               c0
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA                0.94950               c6
#
# [5374 rows x 54 columns]

# %% [markdown]
# Notice how the `obs` for both objects are the same here, since the data for different assays comes from the same set of cells

# %%
all(rna_adata.obs_names == atac_adata.obs_names)
# Out:
# True

# %% [markdown]
# We can access the annotation on features with `adata.var`. In the ATAC object `atac_adata.var` also stores the genomic coordinates of the peaks.

# %%
rna_adata.var
# Out:
#                            gene_id       gene_type    gene_name
# ENSG00000243485  ENSG00000243485.5         lincRNA  MIR1302-2HG
# ENSG00000237613  ENSG00000237613.2         lincRNA      FAM138A
# ENSG00000186092  ENSG00000186092.5  protein_coding        OR4F5
# ENSG00000238009  ENSG00000238009.6         lincRNA   AL627309.1
# ENSG00000239945  ENSG00000239945.1         lincRNA   AL627309.3
# ...                            ...             ...          ...
# ENSG00000212907  ENSG00000212907.2  protein_coding      MT-ND4L
# ENSG00000198886  ENSG00000198886.2  protein_coding       MT-ND4
# ENSG00000198786  ENSG00000198786.2  protein_coding       MT-ND5
# ENSG00000198695  ENSG00000198695.2  protein_coding       MT-ND6
# ENSG00000198727  ENSG00000198727.2  protein_coding       MT-CYB
#
# [34104 rows x 3 columns]

# %%
atac_adata.var
# Out:
#        seqnames     start       end  width strand             name
# 0          chr1    180451    180951    501      *        c7_peak_1
# 1          chr1    181254    181754    501      *        c2_peak_1
# 2          chr1    191223    191723    501      *        c9_peak_1
# 3          chr1    630059    630559    501      *        c6_peak_5
# 4          chr1    633776    634276    501      *        c8_peak_4
# ...         ...       ...       ...    ...    ...              ...
# 467310    chr22  50756935  50757435    501      *    c5_peak_81501
# 467311    chr22  50760237  50760737    501      *   c2_peak_113398
# 467312    chr22  50775143  50775643    501      *   c8_peak_104552
# 467313    chr22  50783378  50783878    501      *  c6_peak_126089b
# 467314    chr22  50807894  50808394    501      *    c7_peak_99013
#
# [467315 rows x 6 columns]

# %% [markdown]
# ## Build `MuData` object
#
# `muon` is a framework for multimodal data analysis with a strong focus on multi-omics.
#
# `muon.MuData` is a multi-modal data container, that comprises a dictionary with `AnnData` objects, one per modality, in its `.mod` attribute. Just as `AnnData` objects themselves, they also contain attributes like `.obs` with annotation of observations (samples or cells), `.obsm` with their multidimensional annotations such as embeddings, etc.

# %%
mdata = mu.MuData({'rna': rna_adata, 'atac': atac_adata})

# %%
## Might be a bug in the muon package, but it doesn't want to recognize that the column names of .obs
# are the same between atac and rna modality
mdata.obs = rna_adata.obs.copy()

# %%
mdata.obs
# Out:
#                                                                      Cell.ID  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA  hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA  hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC  hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC  hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG  hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG
# ...                                                                      ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT  hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA  hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT  hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG  hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA  hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA
#
#                                                   Sample.ID Sample.Age  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA  hft_ctx_w21_dc1r3_r1      pcw21
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA  hft_ctx_w21_dc1r3_r1      pcw21
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC  hft_ctx_w21_dc1r3_r1      pcw21
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC  hft_ctx_w21_dc1r3_r1      pcw21
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG  hft_ctx_w21_dc1r3_r1      pcw21
# ...                                                     ...        ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT  hft_ctx_w21_dc2r2_r2      pcw21
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA  hft_ctx_w21_dc2r2_r2      pcw21
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT  hft_ctx_w21_dc2r2_r2      pcw21
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG  hft_ctx_w21_dc2r2_r2      pcw21
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA  hft_ctx_w21_dc2r2_r2      pcw21
#
#                                       Sample.Batch      Cell.Barcode  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA     b2020_11  AAACAGCCAGCAATAA
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA     b2020_11  AAACATGCACGTTACA
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC     b2020_11  AAACGGATCCATAAGC
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC     b2020_11  AAACGGATCTTGACCC
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG     b2020_11  AAAGCAAGTGATTACG
# ...                                            ...               ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT     b2020_11  TTTGGTAAGAAAGCAT
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA     b2020_11  TTTGGTGCAACCCTAA
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT     b2020_11  TTTGGTGCAGTAGCCT
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG     b2020_11  TTTGTGAAGACAGGCG
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA     b2020_11  TTTGTGTTCGTCCTTA
#
#                                        RNA.Counts  RNA.Features  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA        2494          1435
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA        3485          1632
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC        3490          1967
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC        3331          1666
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG        2436          1414
# ...                                           ...           ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT        7089          2810
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA        4647          2095
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT        5505          2378
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG        4099          1935
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA        6520          2514
#
#                                       Dissociation.ID  percentMT  percentRibo  \
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA               A   0.000796     0.017516
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA               A   0.031098     0.039372
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC               A   0.028865     0.046585
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC               A   0.061920     0.049955
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG               A   0.038430     0.049060
# ...                                               ...        ...          ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT               B   0.052646     0.045346
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA               B   0.032583     0.029582
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT               B   0.008314     0.028556
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG               B   0.061999     0.044979
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA               B   0.001069     0.014207
#
#                                       seurat_clusters
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA             c10
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA              c0
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC              c1
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC              c0
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG              c1
# ...                                               ...
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT              c1
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA              c0
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT              c3
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG              c0
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA              c6
#
# [5374 rows x 11 columns]

# %% [markdown]
# Observations and variables of the `MuData` object are global, which means that observations with the identical name (`.obs_names`) in different modalities are considered to be the same observation. This also means variable names (`.var_names`) should be unique.

# %% [markdown]
# Notably, individual modalities inside the MuData container are stored as references to the original objects and are full-fledged AnnData objects, which can be operated independently with any tool that works on AnnData objects. So if we change the single-omic `AnnData` objects, the changes will be reflected in the container.
#
# For example, if we add a column to the `.obs` of the RNA modality object, we can see the new column is also accessible from the container.

# %%
rna_adata.obs["new_col"] = 0
mdata["rna"]
# Out:
# AnnData object with n_obs × n_vars = 5374 × 34104
#     obs: 'Cell.ID', 'Sample.ID', 'Sample.Age', 'Sample.Batch', 'Cell.Barcode', 'RNA.Counts', 'RNA.Features', 'Dissociation.ID', 'percentMT', 'percentRibo', 'seurat_clusters', 'new_col'
#     var: 'gene_id', 'gene_type', 'gene_name'
#     layers: 'counts'

# %% [markdown]
# However, the column is not found in the common `.obs`

# %%
mdata.obs["rna:new_col"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/my-conda-envs/sc2021-multiomics/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/my-conda-envs/sc2021-multiomics/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/my-conda-envs/sc2021-multiomics/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rna:new_col'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_12080/2532819043.py in <module>
# ----> 1 mdata.obs["rna:new_col"]
#
# ~/my-conda-envs/sc2021-multiomics/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# ~/my-conda-envs/sc2021-multiomics/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'rna:new_col'

# %% [markdown]
# To update the common obs, we can use the `.update_obs()` method, that syncs up the data.

# %%
mdata.update_obs()
mdata.obs["rna:new_col"]
# Out:
# hft_ctx_w21_dc1r3_r1_AAACAGCCAGCAATAA    0
# hft_ctx_w21_dc1r3_r1_AAACATGCACGTTACA    0
# hft_ctx_w21_dc1r3_r1_AAACGGATCCATAAGC    0
# hft_ctx_w21_dc1r3_r1_AAACGGATCTTGACCC    0
# hft_ctx_w21_dc1r3_r1_AAAGCAAGTGATTACG    0
#                                         ..
# hft_ctx_w21_dc2r2_r2_TTTGGTAAGAAAGCAT    0
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAACCCTAA    0
# hft_ctx_w21_dc2r2_r2_TTTGGTGCAGTAGCCT    0
# hft_ctx_w21_dc2r2_r2_TTTGTGAAGACAGGCG    0
# hft_ctx_w21_dc2r2_r2_TTTGTGTTCGTCCTTA    0
# Name: rna:new_col, Length: 5374, dtype: int64

# %% [markdown]
# To update everything we can use `mdata.update()`

# %% [markdown]
# ## Preprocessing RNA modality
#
# For preprocessing the scRNA data we can use the standard functions implemented in `scanpy`. In this case, the data stored in `adata.X` is already log-normalized, and cells have already been filtered by percentage of mitochrondrial counts and total counts, so we start from identifying highly variable genes.

# %%
sc.pp.highly_variable_genes(rna_adata, min_mean=0.02, max_mean=4, min_disp=0.5)

# %%
sc.pl.highly_variable_genes(rna_adata)

# %% [markdown]
# Let's check how many genes are identified as highly variable

# %%
np.sum(rna_adata.var.highly_variable)
# Out:
# 4499

# %% [markdown]
# Next we run dimensionality reduction with PCA and use PCs to construct a K-nearest neighbor graph for visualization of our cells in UMAP

# %%
sc.pp.pca(rna_adata)
sc.pp.neighbors(rna_adata, n_neighbors=10, n_pcs=30)
sc.tl.umap(rna_adata)

# %%
sc.pl.umap(rna_adata, color="seurat_clusters")

# %% [markdown]
# We can see differences in expression of known marker genes for neuronal intermediate progenitor cells (nIPC) and glutamatergic excitatory neurons (GluN)

# %%
marker_genes = {
    "nIPC":['EOMES', 'PPP1R17', 'PENK', 'NEUROG1', 'NEUROG2'],
    "GluN":['NEUROD2', 'TBR1', 'BCL11B', 'SATB2', 'SLC17A7']
               }

rna_adata.var_names = rna_adata.var["gene_name"].values.copy()
sc.pl.umap(rna_adata, color=marker_genes["nIPC"])
sc.pl.umap(rna_adata, color=marker_genes["GluN"])
# Out:
# /home/jovyan/my-conda-envs/sc2021-multiomics/lib/python3.9/site-packages/anndata/_core/anndata.py:891: UserWarning:
# AnnData expects .var.index to contain strings, but got values like:
#     ['MIR1302-2HG', 'FAM138A', 'OR4F5', 'AL627309.1', 'AL627309.3']
#
#     Inferred to be: categorical
#
#   names = self._prep_dim_index(names, "var")

# %% [markdown]
# Finally, we can use ordinary diffusion pseudotime to order excitatory neurons along a differentiation trajectory stemming from the nIPCs.

# %%
sc.tl.diffmap(rna_adata)
sc.pl.diffmap(rna_adata, color=marker_genes['nIPC'])

# %%
## Define the putative root cell (start of differentiation trajectory)
## we take the minimum for DC1 as the root nIPC
rna_adata.uns['iroot'] = rna_adata.obsm["X_diffmap"][:,1].argmin() 
sc.tl.dpt(rna_adata)
sc.pl.umap(rna_adata, color=["dpt_pseudotime"])

# %% [markdown]
# We can already observe different patterns of expression along pseudotime for the GluN marker genes

# %%
for g in marker_genes["GluN"]:
    sc.pl.scatter(rna_adata, 'dpt_pseudotime', g)

# %% [markdown]
# ---

# %% [markdown]
# ## Preprocessing ATAC modality
#
# We are going to use the functions for preprocessing of scATAC data in python implemented in `muon`

# %%
from muon import atac as ac

# %% [markdown]
# Again, here QC metrics such as the signal at Transcriptional Start Sites and cell and gene filtering was already performed. Let's recalculate QC metric just to check the distribution of certain metrics

# %%
sc.pp.calculate_qc_metrics(atac_adata, percent_top=None, log1p=False, inplace=True)

# %%
sc.pl.violin(atac_adata, ['total_counts', 'n_genes_by_counts'], jitter=0.4, multi_panel=True)

# %% [markdown]
# We now binarize the count matrix: since scATAC data is extremely sparse and most non-zero values in it are 1 and 2.

# %%
ac.pp.binarize(atac_adata)

# %% [markdown]
# Then we normalize the data using TF-IDF (Term Frequency - Inverse Document Frequency). This is a normalization technique adapted from text processing, in this case we consider each peak as a "term" and each cell as a "document". This is typically followed by singular value decomposition (SVD) — the same technique that convential principal component analysis (PCA) uses — to generate latent components, and these two steps together are referred to as latent semantic indexing (LSI).

# %%
ac.pp.tfidf(atac_adata, scale_factor=1e4)
# Out:
# /home/jovyan/my-conda-envs/sc2021-multiomics/lib/python3.9/site-packages/muon/_atac/preproc.py:64: RuntimeWarning: divide by zero encountered in true_divide
#   idf = np.asarray(adata.shape[0] / adata.X.sum(axis=0)).reshape(-1)

# %%
## For the PCA step, we can use the standard scanpy function or ac.pp.lsi
sc.pp.pca(atac_adata)

# %% [markdown]
# A word of caution on LSI: typically we see that the first latent factor or the first few latent factors found with this procedure are very strongly correlated with the total counts in the cells. Some workflows suggest excluding these latent factors that simply capture the coverage. In practice, it's not straight-forward to decide which latent factors whould be kept and which should be excluded, so for now we keep them all.

# %%
atac_adata.obsm["X_lsi"] = atac_adata.obsm["X_pca"].copy()
atac_adata.obs["LSI_f1"] = atac_adata.obsm["X_lsi"][:,0]
atac_adata.obs["LSI_f2"] = atac_adata.obsm["X_lsi"][:,1]

# %%
sc.pl.scatter(atac_adata, "total_counts", "LSI_f1")
sc.pl.scatter(atac_adata, "total_counts", "LSI_f2")

# %% [markdown]
# We can now compute a KNN graph for clustering and UMAP

# %%
sc.pp.neighbors(atac_adata, use_rep="X_lsi", n_neighbors=10, n_pcs=30)
sc.tl.umap(atac_adata)

# %%
sc.pl.umap(atac_adata, color="seurat_clusters")

# %% [markdown]
# As for the RNA, we can use ordinary diffusion pseudotime to order excitatory neurons along a differentiation trajectory stemming from the nIPCs.

# %%
sc.tl.diffmap(atac_adata)
sc.pl.diffmap(atac_adata, color="seurat_clusters")

# %%
## Let's use the same root cell used in RNA
atac_adata.uns['iroot'] = rna_adata.uns['iroot'].copy()
sc.tl.dpt(atac_adata)
sc.pl.umap(atac_adata, color=["dpt_pseudotime"])

# %% [markdown]
# ---

# %% [markdown]
# ## Multi-modal analysis

# %% [markdown]
# Now it's time to start the joint analysis of scRNA and scATAC, where we aim to identify non-coding chromatin regions associated with expression of variable genes during excitatory neuron development.

# %% [markdown]
# Firstly, let's save the progress we've done on the single-modalities in the `.obs` of the multi-omic object container

# %%
mdata.update_obs()

# %% [markdown]
# Now we can jointly visualize ATAC and RNA features. For example, let's check the correspondance between the pseudotime trajectory inferred on scRNA and on scATAC.

# %%
plt.rcParams["figure.figsize"] = [7,7]
sc.pl.scatter(mdata, "rna:dpt_pseudotime", "atac:dpt_pseudotime", color='seurat_clusters')

# %% [markdown]
# Looking at this plot, we can speculate that cells in the initial stages of differentiation from nIPCs seem to progress "faster" in ATAC pseudotime than in RNA pseudotime, while the opposite is true towards the end of the differentiation trajectory. This supports the notion of chromatin accessibility changes preceding RNA expression changes during development.
#
# But let's do some real analysis...

# %% [markdown]
# ---

# %% [markdown]
# ## Multi-modal embedding
# Let's try two different ways to project cells in a latent space that incorporates information from both modalities (as opposed to e.g. running PCA and clustering on the RNA modality and seeing how it segregates ATAC data).
#
#
# ### Weighted Nearest Neighbors
#
# We start by using the Weighted Nearest Neighbor (WNN) method presented in [Cao et al. 2021](https://www.cell.com/cell/fulltext/S0092-8674(21)00583-3?_returnURL=https%3A%2F%2Flinkinghub.elsevier.com%2Fretrieve%2Fpii%2FS0092867421005833%3Fshowall%3Dtrue). We use the python reimplementation found in `muon`. We first need to calculate the KNN graph for each modality.

# %%
mu.pp.neighbors(mdata)
# Out:
# /home/jovyan/my-conda-envs/sc2021-multiomics/lib/python3.9/site-packages/pynndescent/pynndescent_.py:339: NumbaWarning: Cannot cache compiled function "generate_leaf_updates" as it uses dynamic globals (such as ctypes pointers and large global arrays)
#   init_rp_tree(data, dist, current_graph, leaf_array)
# /home/jovyan/my-conda-envs/sc2021-multiomics/lib/python3.9/site-packages/pynndescent/pynndescent_.py:339: NumbaWarning: Cannot cache compiled function "init_rp_tree" as it uses dynamic globals (such as ctypes pointers and large global arrays)
#   init_rp_tree(data, dist, current_graph, leaf_array)
# /home/jovyan/my-conda-envs/sc2021-multiomics/lib/python3.9/site-packages/pynndescent/pynndescent_.py:341: NumbaWarning: Cannot cache compiled function "init_random" as it uses dynamic globals (such as ctypes pointers and large global arrays)
#   init_random(n_neighbors, data, current_graph, dist, rng_state)
# /home/jovyan/my-conda-envs/sc2021-multiomics/lib/python3.9/site-packages/pynndescent/pynndescent_.py:351: NumbaWarning: Cannot cache compiled function "generate_graph_updates" as it uses dynamic globals (such as ctypes pointers and large global arrays)
#   nn_descent_internal_low_memory_parallel(
# /home/jovyan/my-conda-envs/sc2021-multiomics/lib/python3.9/site-packages/pynndescent/pynndescent_.py:351: NumbaWarning: Cannot cache compiled function "process_candidates" as it uses dynamic globals (such as ctypes pointers and large global arrays)
#   nn_descent_internal_low_memory_parallel(

# %% [markdown]
# The WNN graph is stored as a `.obsp` slot common to both modalities

# %%
mdata.obsp
# Out:
# PairwiseArrays with keys: distances, connectivities

# %% [markdown]
# We can then use this common graph for UMAP embedding

# %%
mu.tl.umap(mdata)

# %%
sc.pl.umap(mdata, color="seurat_clusters", title="Multi-modal embedding (WNN)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_144/2516292764.py in <module>
# ----> 1 sc.pl.umap(mdata, color="seurat_clusters", title="Multi-modal embedding (WNN)")
#
# NameError: name 'sc' is not defined

# %%
sc.pl.umap(mdata["rna"], color="seurat_clusters", title="RNA embedding")
sc.pl.umap(mdata["atac"], color="seurat_clusters", title="ATAC embedding")

# %% [markdown]
# Let's save our progress in a `.h5mu` object

# %%
mdata.write("../processed_data/Multiome_ext_trajectory.h5mu")

# %% [markdown]
# ### Multi-Omics Factor analysis
#
# Another method for multi-modal latent embedding is [Multi Omics Factor Analysis](https://github.com/bioFAM/MOFA2). This is also implemented in `muon`. For MOFA it's better to select highly variable peaks

# %%
sc.pp.highly_variable_genes(atac_adata, flavor="seurat", n_top_genes=10000)
mdata.update() ## to save in mdata.var

# %%
mu.tl.mofa(mdata, use_var="highly_variable")
# Out:
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
# Loaded view='rna' group='group1' with N=5374 samples and D=4499 features...
# Loaded view='atac' group='group1' with N=5374 samples and D=10000 features...
#
#
# Model options:
# - Automatic Relevance Determination prior on the factors: True
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: True
# Likelihoods:
# - View 0 (rna): gaussian
# - View 1 (atac): gaussian
#
#
#
#
# ######################################
# ## Training the model with seed 1 ##
# ######################################
#
#
#
#
# #######################
# ## Training finished ##
# #######################
#
#
# Saving model in /tmp/mofa_20210807-210629.hdf5...
# Note: the model to be saved is not trained.
# Saved MOFA embeddings in .obsm['X_mofa'] slot and their loadings in .varm['LFs'].

# %% [markdown]
# ---

# %% [markdown]
# ## Infer differentiation trajectories
#
# Let's try to infer trajectory with diffusion pseudotime with KNN graphs from different modalities or with WNN graph

# %%
sc.tl.diffmap(mdata)

# %%
sc.pl.diffmap(mdata, color="seurat_clusters")

# %%
mdata.update_obs()

# %%
sc.pl.umap(mdata, color=["dpt_pseudotime","rna:dpt_pseudotime", "atac:dpt_pseudotime"])

# %%
sc.pl.scatter(mdata, "dpt_pseudotime", "rna:dpt_pseudotime" , color="seurat_clusters")
sc.pl.scatter(mdata, "dpt_pseudotime", "atac:dpt_pseudotime", color="seurat_clusters")

# %% [markdown]
# ---

# %% [markdown]
# ## Associating gene expression to accessibility

# %% [markdown]
# We first want to find genes that have variable expression in pseudotime. We will restrict the search to peaks associated to these variable genes.
#
# We take a naive approach, correlating log-counts in expression to the value of pseudotime in the joint embedding. For better approaches to find variable genes in pseudotime, see (A) cellrank, (B) tradeSeq and (C) ...
#
# **consider aggregating cells by pseudotime or clusters**

# %%
from scipy.stats import pearsonr
X_logcounts = mdata['rna'].X.T
keep_genes = np.where(X_logcounts.sum(1) > 50)[0]
X_logcounts = X_logcounts[keep_genes,:] ## filter genes with > 50 counts across all cells
mdata['rna'].var["dpt_corr_r2"] = np.nan
mdata['rna'].var["dpt_corr_r2"] = np.nan
for i in range(X_logcounts.shape[0]):
    r2,pval = pearsonr(mdata.obs["dpt_pseudotime"],X_logcounts[i,:].toarray().flatten())
    mdata['rna'].var.loc[mdata.var_names[keep_genes[i]],"dpt_corr_r2"] = r2
    mdata['rna'].var.loc[mdata.var_names[keep_genes[i]],"dpt_corr_pval"] = pval

# %%
## Adjust for multiple testing
from statsmodels.stats import multitest
_,adj_pvals,_,_ = multitest.multipletests(mdata['rna'].var["dpt_corr_pval"].dropna(), method="fdr_bh")

# %%
mdata['rna'].var["dpt_corr_adj_pval"] = np.nan
mdata['rna'].var.loc[~mdata['rna'].var["dpt_corr_pval"].isna(), "dpt_corr_adj_pval"] = adj_pvals

# %% [markdown]
# Let's see how the correlations look like

# %%
mdata['rna'].var["dpt_corr_neg_log10_pval"] = -np.log10(mdata['rna'].var["dpt_corr_adj_pval"])
sc.pl.scatter(mdata['rna'], "dpt_corr_r2", "dpt_corr_neg_log10_pval")

# %% [markdown]
# We define as associated to pseudotime genes with absolute correlation > 0.2

# %%
mdata['rna'].var["dpt_associated_gene"] = abs(mdata['rna'].var["dpt_corr_r2"]) > 0.2

# %% [markdown]
# Let's plot the expression of these genes

# %%
mdata["rna"][:,mdata['rna'].var["dpt_associated_gene"]].X.toarray()
# Out:
# array([[0.       , 1.6113607, 0.       , ..., 0.       , 0.       ,
#         1.6113607],
#        [0.       , 0.       , 0.       , ..., 3.5676517, 2.523948 ,
#         3.6455212],
#        [0.       , 1.352047 , 0.       , ..., 3.3895733, 2.9009807,
#         3.2879527],
#        ...,
#        [0.       , 0.       , 1.0355058, ..., 2.1121655, 2.1121655,
#         1.5332178],
#        [1.2353609, 0.       , 0.       , ..., 4.5137773, 3.9556954,
#         3.9078622],
#        [0.       , 0.       , 0.       , ..., 0.       , 1.7229856,
#         0.       ]], dtype=float32)

# %%
## Extract expression matrix with genes ordered by pseudotime
dpt_order_gex_matrix = mdata["rna"][mdata.obs["dpt_pseudotime"].argsort(),mdata['rna'].var["dpt_associated_gene"]].X.toarray()
dpt_order_gex_matrix = sc.pp.scale(dpt_order_gex_matrix)
dpt_order_gex_matrix = pd.DataFrame(dpt_order_gex_matrix.T)
dpt_order_gex_matrix.index = mdata['rna'].var_names[mdata['rna'].var["dpt_associated_gene"]]

import seaborn as sns
plt.rcParams["figure.figsize"] = [10,10]
sns.clustermap(dpt_order_gex_matrix, xticklabels=False, col_cluster=False, cmap="RdBu",
              vmin=-8, vmax=8)

# %% [markdown]
# Next, we identify peaks that are close to these genes, within 50 kb.

# %%
genes_oi = mdata['rna'].var_names[mdata['rna'].var["dpt_associated_gene"]]

# %%
peaks = mdata['atac'].var["seqnames"].astype("str") + ":" +\
mdata['atac'].var["start"].astype("str") + '-' +\
mdata['atac'].var["end"].astype("str")

# %%
peaks = mdata['atac'].var[["seqnames", "start", "end"]]

# %% [markdown]
# Let's set up `rpy2` usage to use R functions within this python notebook: I use the annotations in `ensembldb` to extract genomic positions for these genes and I use `GenomicRanges` to do feature overlaps.

# %%
import anndata2ri

# %%
import rpy2.rinterface_lib.callbacks
import logging

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# library(tidyr)
# library(Matrix)
# library(ensembldb)
# library(EnsDb.Hsapiens.v86) ## Remember to pick your genome!
# Out:
# R[write to console]:
# Attaching package: 'Matrix'
#
#
# R[write to console]: The following objects are masked from 'package:tidyr':
#
#     expand, pack, unpack
#
#
# R[write to console]: The following object is masked from 'package:S4Vectors':
#
#     expand

# %%
# %%R
# ## String - GRanges conversion
# ## Borrowed from Signac functions
# ## https://satijalab.org/signac/reference/GRangesToString.html
# StringToGRanges <- function(regions, sep = c("-", "-"), ...) {
#   ranges.df <- data.frame(ranges = regions)
#   ranges.df <- separate(
#     data = ranges.df,
#     col = "ranges",
#     sep = paste0(sep[[1]], "|", sep[[2]]),
#     into = c("chr", "start", "end")
#   )
#   granges <- makeGRangesFromDataFrame(df = ranges.df, ...)
#   return(granges)
# }
#
# GRangesToString <- function(grange, sep = c("-", "-")) {
#   regions <- paste0(
#     as.character(x = seqnames(x = grange)),
#     sep[[1]],
#     start(x = grange),
#     sep[[2]],
#     end(x = grange)
#   )
#   return(regions)
# }
#
# # Extend genomicRanges
# #
# extend <- function(x, upstream=0, downstream=0)
# {
#     if (any(strand(x) == "*"))
#         warning("'*' ranges were treated as '+'")
#     on_plus <- strand(x) == "+" | strand(x) == "*"
#     new_start <- start(x) - ifelse(on_plus, upstream, downstream)
#     new_end <- end(x) + ifelse(on_plus, downstream, upstream)
#     ranges(x) <- IRanges(new_start, new_end)
#     trim(x)
# }
#
#
# # Find peaks close to features of interest
# #
# # @param peaks_gr GenomicRanges object containing peaks
# # @param features_gr GenomicRanges object containing features (e.g. genes)
# # @param d distance to include peak, in bps (default 50000)
# # @param feat_anno column in `features_gr@elementMetadata` containing annotation to name features (if NULL converts Granges to string)
# #
# # @return Sparse adjacency matrix indicating hits
# peak2feature <- function(peaks_gr, features_gr, d=50000, feat_anno=NULL){
#   seqlevelsStyle(features_gr) <- seqlevelsStyle(peaks_gr)
#
#   ## Find peaks overlapping the search range around the features
#   ext_gr <- extend(features_gr, upstream = d, downstream = d)
#   ovs <- findOverlaps(peaks_gr, ext_gr)
#
#   ## Define identifiers for peaks and features
#   all_peaks <- GRangesToString(peaks_gr, sep = c(":", '-'))
#   if (is.null(feat_anno)) {
#     all_feats <- GRangesToString(features_gr, sep = c(":", '-'))
#   } else {
#     all_feats <- features_gr@elementMetadata[[feat_anno]]
#   }
#
#   ## Build adjacency matrix for hits
#   adj_mat <- Matrix(data=0, nrow = length(all_peaks), ncol=length(all_feats))
#   for (i in unique(subjectHits(ovs))) {
#     # if (length(adj_mat[queryHits(ovs[subjectHits(ovs)==i]),i]) > 0) {
#     adj_mat[queryHits(ovs[subjectHits(ovs)==i]),i] <- 1
#     # }
#   }
#   colnames(adj_mat) <- all_feats
#   rownames(adj_mat) <- all_peaks
#
#   adj_mat
#
# }

# %%
# %%R  -i peaks -i genes_oi -o adj_mat
# genes_gr <- genes(EnsDb.Hsapiens.v86)[genes_oi]
# peaks_gr <- makeGRangesFromDataFrame(peaks)
#
# ## Compute peak2gene adjacency matrix
# adj_mat <- peak2feature(peaks_gr, genes_gr, feat_anno = "gene_id", d=50000)

# %%
adj_mat = anndata2ri.r2py.rmat_to_spmat(adj_mat)

# %% [markdown]
# How many peaks are close to these genes?

# %%
np.array((adj_mat.T.sum(0) != 0)).ravel()
# Out:
# 68834

# %% [markdown]
# We save the association of peaks to genes in the `.varm` slot of the `atac` modality

# %%
mdata["atac"].varm["peak2gene_matching"] = adj_mat

# %% [markdown]
# Now we can test for associations using pearson's correlation. To increase the power here, we aggregate peak and gene counts by bins of pseudotime.

# %%
mdata.obs["dpt_pseudotime_bin"] = pd.cut(mdata.obs["dpt_pseudotime"], bins=500).astype("category").cat.codes

# %%
# ...

# %%
# ...
# Out:
# <5374x351 sparse matrix of type '<class 'numpy.float32'>'
# 	with 29601 stored elements in Compressed Sparse Row format>
